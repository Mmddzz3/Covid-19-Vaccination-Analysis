# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("country_vaccinations.csv")
data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name  \
# 0  World Health Organization
# 1  World Health Organization
# 2  World Health Organization
# 3  World Health Organization
# 4  World Health Organization
#
#                                       source_website
# 0  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 1  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 2  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 3  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...
# 4  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.345700e+04       2.237100e+04             1.946200e+04
# mean         1.869182e+07       8.018487e+06             4.958000e+06
# std          1.074242e+08       3.003110e+07             1.777390e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.907310e+05       1.555315e+05             7.318550e+04
# 50%          1.347062e+06       9.394600e+05             5.620635e+05
# 75%          7.128593e+06       4.346202e+06             2.825012e+06
# max          2.113083e+09       1.072500e+09             8.894390e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.925100e+04        4.255800e+04
# mean             2.578764e+05        1.298099e+05
# std              1.330061e+06        8.886442e+05
# min              0.000000e+00        0.000000e+00
# 25%              5.001000e+03        8.642500e+02
# 50%              2.409500e+04        6.911500e+03
# 75%              1.096070e+05        4.125600e+04
# max              2.474100e+07        2.242429e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    23457.000000                   22371.000000
# mean                        40.940397                      25.036586
# std                         43.123247                      23.724454
# min                          0.000000                       0.000000
# 25%                          4.800000                       3.715000
# 50%                         23.920000                      16.700000
# 75%                         67.700000                      43.340000
# max                        234.150000                     117.710000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         19462.000000                    42558.000000
# mean                             18.165081                     3567.049086
# std                              20.371328                     4497.458118
# min                               0.000000                        0.000000
# 25%                               2.110000                      501.000000
# 50%                               9.355000                     2180.000000
# 75%                              28.797500                     5337.000000
# max                             116.440000                   117497.000000

# %%
pd.to_datetime(data.date)
data.country.value_counts()
# Out:
# Norway                             278
# Latvia                             277
# England                            272
# Scotland                           272
# United Kingdom                     267
#                                   ...
# Haiti                               50
# Pitcairn                            49
# Tanzania                            21
# Bonaire Sint Eustatius and Saba      1
# Turkmenistan                         1
# Name: country, Length: 222, dtype: int64

# %%
data = data[data.country.apply(lambda x: x not in ["England", "Scotland", "Wales", "Northern Ireland"])]
data.country.value_counts()
# Out:
# Norway                             278
# Latvia                             277
# United Kingdom                     267
# Canada                             267
# Russia                             266
#                                   ...
# Niue                                50
# Pitcairn                            49
# Tanzania                            21
# Bonaire Sint Eustatius and Saba      1
# Turkmenistan                         1
# Name: country, Length: 218, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech     5396
# Oxford/AstraZeneca                                                5063
# Oxford/AstraZeneca, Sinopharm/Beijing                             2868
# Oxford/AstraZeneca, Pfizer/BioNTech                               2844
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                      2706
#                                                                   ...
# Moderna, Oxford/AstraZeneca, Sinovac                               117
# Abdala, Soberana02                                                 109
# Covaxin, Oxford/AstraZeneca                                        106
# Johnson&Johnson                                                     21
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V       1
# Name: vaccines, Length: 69, dtype: int64

# %%
df = data[["vaccines", "country"]]
df.head()
# Out:
#                                             vaccines      country
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan

# %%
dict_ = {}
for i in df.vaccines.unique():
  dict_[i] = [df["country"][j] for j in df[df["vaccines"]==i].index]

vaccines = {}
for key, value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")
# Out:
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Afghanistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Oman', 'Albania', 'Bosnia and Herzegovina'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Algeria'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Australia', 'Grenada', 'Panama', 'Cape Verde', 'Saint Kitts and Nevis', 'Costa Rica', 'Andorra', 'Kosovo', 'Bermuda', 'Isle of Man', 'Cayman Islands', 'Slovenia', 'Saudi Arabia'}
# Oxford/AstraZeneca:>>{'Anguilla', 'Cook Islands', 'Wallis and Futuna', 'Ethiopia', 'Liberia', 'Eswatini', 'Pitcairn', 'Democratic Republic of Congo', 'Fiji', 'Angola', 'Tuvalu', 'Sao Tome and Principe', 'Lesotho', 'Niue', 'Saint Helena', 'Suriname', 'Samoa', 'Togo', 'South Sudan', 'Mali', 'Kiribati', 'Nigeria', 'Tonga', 'Yemen', 'Saint Vincent and the Grenadines', 'Montserrat', 'Falkland Islands', 'Bahamas', "Cote d'Ivoire", 'Antigua and Barbuda', 'Nauru', 'Burkina Faso', 'Madagascar', 'Saint Lucia', 'Uganda'}
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Argentina', 'Congo'}
# Oxford/AstraZeneca, Sinovac, Sputnik V:>>{'Azerbaijan', 'Armenia'}
# Pfizer/BioNTech:>>{'New Caledonia', 'Kuwait', 'Monaco', 'Tokelau', 'Turks and Caicos Islands', 'New Zealand', 'Aruba', 'Gibraltar'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Germany', 'Bulgaria', 'Lithuania', 'Estonia', 'Cyprus', 'Malta', 'Romania', 'Belgium', 'Iceland', 'Poland', 'Greece', 'Jamaica', 'Italy', 'Netherlands', 'South Korea', 'France', 'Latvia', 'Ireland', 'Portugal', 'Czechia', 'Spain', 'Austria'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Mongolia', 'Iraq', 'Lebanon', 'Bahrain', 'Jordan', 'Serbia', 'Montenegro'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Bhutan', 'Bangladesh'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Barbados', 'Maldives', 'Dominica', 'Peru'}
# Sinopharm/Beijing, Sputnik V:>>{'Belarus', 'Kyrgyzstan'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Brunei', 'Zambia', 'Mauritania', 'Sierra Leone', 'Guinea-Bissau', 'Solomon Islands', 'Vanuatu', 'Cameroon', 'Mozambique', 'Seychelles', 'Belize', 'Nepal', 'Niger', 'Trinidad and Tobago', 'Morocco', 'Senegal', 'Namibia'}
# Oxford/AstraZeneca, Sinovac:>>{'Benin', 'Timor', 'Thailand'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Moldova', 'Bolivia'}
# Moderna, Pfizer/BioNTech:>>{'Israel', 'Curacao', 'Faeroe Islands', 'Norway', 'Bonaire Sint Eustatius and Saba', 'Switzerland', 'Qatar', 'Liechtenstein'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Ukraine', 'Botswana'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Brazil'}
# Johnson&Johnson, Oxford/AstraZeneca:>>{'Haiti', 'British Virgin Islands', 'Malawi'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Somalia', 'Cambodia'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Rwanda', 'Guernsey', 'Jersey', 'United Kingdom', 'Finland', 'Japan', 'Luxembourg', 'Croatia', 'Slovakia', 'Sweden', 'Sint Maarten (Dutch part)', 'Canada'}
# Covaxin, Oxford/AstraZeneca:>>{'Central African Republic'}
# Sinopharm/Beijing:>>{'Chad', 'Gabon', 'Equatorial Guinea'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Chile', 'Malaysia'}
# CanSino, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac, ZF2001:>>{'China'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Colombia'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Comoros', 'Mauritius'}
# Abdala, Soberana02:>>{'Cuba'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'Denmark', 'United States'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Djibouti', 'Egypt', 'Laos'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Georgia', 'Dominican Republic'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'El Salvador', 'Northern Cyprus', 'Uruguay', 'Ecuador'}
# Johnson&Johnson, Pfizer/BioNTech:>>{'French Polynesia', 'South Africa'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Papua New Guinea', 'Gambia'}
# Oxford/AstraZeneca, Sputnik V:>>{'Ghana', 'Guyana', 'Nicaragua', 'Kenya'}
# Moderna:>>{'Greenland'}
# Moderna, Oxford/AstraZeneca:>>{'Guatemala'}
# Sputnik V:>>{'Guinea'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Honduras'}
# Pfizer/BioNTech, Sinovac:>>{'Hong Kong', 'Turkey'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca, Sputnik V:>>{'India'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Indonesia'}
# COVIran Barekat, Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Iran'}
# QazVac, Sinopharm/HayatVax, Sputnik V:>>{'Kazakhstan'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Libya', 'Tunisia'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Macao'}
# CanSino, Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Myanmar'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'North Macedonia'}
# CanSino, Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Palestine'}
# Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Paraguay'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Philippines'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Moderna, Pfizer/BioNTech, Sinovac:>>{'Singapore'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Sri Lanka', 'Vietnam'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Sudan'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Syria'}
# Medigen, Moderna, Oxford/AstraZeneca:>>{'Taiwan'}
# Moderna, Oxford/AstraZeneca, Sinovac:>>{'Tajikistan'}
# Johnson&Johnson:>>{'Tanzania'}
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Turkmenistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Oxford/AstraZeneca, Sputnik V, ZF2001:>>{'Uzbekistan'}
# Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'Venezuela'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Zimbabwe'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-eea3d3142d68> in <module>
# ----> 1 import plotly.express as px
#       2 import plotly.offline as py
#       3
#       4 vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
#       5 vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\__init__.py in <module>
#      13     )
#      14
# ---> 15 from ._imshow import imshow
#      16 from ._chart_types import (  # noqa: F401
#      17     scatter,
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_imshow.py in <module>
#       1 import plotly.graph_objs as go
#       2 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 3 from ._core import apply_default_cascade, init_figure, configure_animation_controls
#       4 from .imshow_utils import rescale_intensity, _integer_ranges, _integer_types
#       5 import pandas as pd
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py in <module>
#       6
#       7 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 8 from plotly.colors import qualitative, sequential
#       9 import math
#      10 import pandas as pd
#
# ImportError: cannot import name 'qualitative' from 'plotly.colors' (C:\ProgramData\Anaconda3\lib\site-packages\plotly\colors.py)
